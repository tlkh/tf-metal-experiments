# %%
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format='retina'

# %%
bs_list = [0, 1, 2, 8, 32, 128, 256, 512]
ane_list = [0, 37.68, 69.81, 198.07, 343.58, 394.52, 424.18]
gpu_list = [0, 29.98, 56.23, 203.07, 463.58, 593.21, 673.56, 710.25]

# %%
plt.figure(figsize=(10,5))
plt.title("ResNet50 Inference (CoreML)")
plt.ylabel("Images/second")
plt.xlabel("Batch Size")
plt.plot(bs_list[:-1], ane_list, label="ANE FP16", linewidth=1)
plt.plot(bs_list, gpu_list, label="GPU (32c) FP16", linewidth=1)
plt.xlim(-1, 275)
plt.ylim(0, 740)
plt.legend()
plt.show()
